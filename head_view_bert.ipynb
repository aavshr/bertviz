# %%
from bertviz.pytorch_transformers_attn import BertConfig, BertModel, BertTokenizer
from bertviz.head_view_bert import show

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min',
#       jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#   }
# });

# %%
MODEL_CHECKPOINT_DIR = '/home/aavash/Desktop/thesis/src/classification/checkpoints/atelectasis/renamed/'
#MODEL_CHECKPOINT_DIR = '/home/aavash/Desktop/thesis/bert/bert-base-uncased/uncased_L-12_H-768_A-12/'

# %%
bert_version = 'bert-base-uncased'
config = BertConfig.from_pretrained(bert_version)
#model = BertForSequenceClassification.from_pretrained(bert_version)
tokenizer = BertTokenizer.from_pretrained(bert_version)

# %%
model = BertModel.from_pretrained(MODEL_CHECKPOINT_DIR, from_tf=True, config=config)
# Out:
# embeddings.LayerNorm.bias	 Shape: torch.Size([768])
# Tf shape: (768,)
# embeddings.LayerNorm.weight	 Shape: torch.Size([768])
# Tf shape: (768,)
# embeddings.position_embeddings.weight	 Shape: torch.Size([512, 768])
# Tf shape: (512, 768)
# embeddings.token_type_embeddings.weight	 Shape: torch.Size([2, 768])
# Tf shape: (2, 768)
# embeddings.word_embeddings.weight	 Shape: torch.Size([30522, 768])
# Tf shape: (30522, 768)
# encoder.layer.0.attention.output.LayerNorm.bias	 Shape: torch.Size([768])
# Tf shape: (768,)
# encoder.layer.0.attention.output.LayerNorm.weight	 Shape: torch.Size([768])
# Tf shape: (768,)
# encoder.layer.0.attention.output.dense.bias	 Shape: torch.Size([768])
# Tf shape: (768,)
# encoder.layer.0.attention.output.dense.weight	 Shape: torch.Size([768, 768])
# Tf shape: (768, 768)
# encoder.layer.0.attention.self.key.bias	 Shape: torch.Size([768])
# Tf shape: (768,)
# encoder.layer.0.attention.self.key.weight	 Shape: torch.Size([768, 768])
# Tf shape: (768, 768)
# ...

# %%
sentence_a = "Atelectasis was found in the report"
sentence_b = ""
#show(model, tokenizer, sentence_a, sentence_b)

# %%
show(model, tokenizer, sentence_a, sentence_b)
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#         Attention: <select id="filter">
#           <option value="all">All</option>
#           <option value="aa">Sentence A -> Sentence A</option>
#           <option value="ab">Sentence A -> Sentence B</option>
#           <option value="ba">Sentence B -> Sentence A</option>
#           <option value="bb">Sentence B -> Sentence B</option>
#         </select>
#       </span>
#       <div id='vis'></div>
